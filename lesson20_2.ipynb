# %%
import yfinance as yf
data = yf.download("SPY AAPL", period="1mo")
data
# Out:
# [*********************100%%**********************]  2 of 2 completed
# Price        Adj Close                   Close                    High  \
# Ticker            AAPL         SPY        AAPL         SPY        AAPL
# Date
# 2024-06-18  214.289993  546.726196  214.289993  548.489990  218.630005
# 2024-06-20  209.679993  545.240967  209.679993  547.000000  214.240005
# 2024-06-21  207.490005  544.510010  207.490005  544.510010  211.889999
# 2024-06-24  208.139999  542.739990  208.139999  542.739990  212.699997
# 2024-06-25  209.070007  544.830017  209.070007  544.830017  211.380005
# 2024-06-26  213.250000  545.510010  213.250000  545.510010  214.860001
# 2024-06-27  214.100006  546.369995  214.100006  546.369995  215.740005
# 2024-06-28  210.619995  544.219971  210.619995  544.219971  216.070007
# 2024-07-01  216.750000  545.340027  216.750000  545.340027  217.509995
# 2024-07-02  220.270004  549.010010  220.270004  549.010010  220.380005
# ...

# %%
import yfinance as yf
data = yf.download("2330.TW", start="2022-01-01",end="2023-12-31")
tw2330 = data[['Adj Close']]
tw2330.columns = ['台積電']
tw2330
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    台積電
# Date
# 2022-01-03  599.505737
# 2022-01-04  623.257935
# 2022-01-05  617.557373
# 2022-01-06  611.856812
# 2022-01-07  602.356079
# ...                ...
# 2023-12-25  576.073120
# 2023-12-26  581.030701
# 2023-12-27  586.979797
# 2023-12-28  587.971313
# 2023-12-29  587.971313
#
# [485 rows x 1 columns]

# %%
import yfinance as yf
data = yf.download("2303.TW", start="2022-01-01",end="2023-12-31")
tw2303 = data[['Adj Close']]
tw2303.columns = ['聯電']
tw2303
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    聯電
# Date
# 2022-01-03  52.592525
# 2022-01-04  52.260708
# 2022-01-05  52.343662
# 2022-01-06  52.011848
# 2022-01-07  51.928898
# ...               ...
# 2023-12-25  47.553146
# 2023-12-26  48.121510
# 2023-12-27  50.679150
# 2023-12-28  49.731876
# 2023-12-29  49.826603
#
# [485 rows x 1 columns]

# %%
import yfinance as yf
data = yf.download("2317.TW", start="2022-01-01",end="2023-12-31")
tw2317 = data[['Adj Close']]
tw2317.columns = ['鴻海']
tw2317
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                     鴻海
# Date
# 2022-01-03   91.097260
# 2022-01-04   91.539482
# 2022-01-05   96.403900
# 2022-01-06   94.635017
# 2022-01-07   94.192802
# ...                ...
# 2023-12-25  100.912506
# 2023-12-26  101.400002
# 2023-12-27  100.912506
# 2023-12-28  101.400002
# 2023-12-29  101.887505
#
# [485 rows x 1 columns]

# %%
import yfinance as yf
data = yf.download("2454.TW", start="2022-01-01",end="2023-12-31")
tw2454 = data[['Adj Close']]
tw2454.columns = ['聯發科']
tw2454
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    聯發科
# Date
# 2022-01-03  900.394531
# 2022-01-04  912.138794
# 2022-01-05  919.968384
# 2022-01-06  888.650269
# 2022-01-07  861.247009
# ...                ...
# 2023-12-25  948.339050
# 2023-12-26  953.104675
# 2023-12-27  991.228821
# 2023-12-28  976.932190
# 2023-12-29  967.401184
#
# [485 rows x 1 columns]

# %%
import pandas as pd
frame = pd.concat([tw2303, tw2317, tw2330, tw2454], axis = 1)
frame
# Out:
#                    聯電          鴻海         台積電         聯發科
# Date
# 2022-01-03  52.592525   91.097260  599.505737  900.394531
# 2022-01-04  52.260708   91.539482  623.257935  912.138794
# 2022-01-05  52.343662   96.403900  617.557373  919.968384
# 2022-01-06  52.011848   94.635017  611.856812  888.650269
# 2022-01-07  51.928898   94.192802  602.356079  861.247009
# ...               ...         ...         ...         ...
# 2023-12-25  47.553146  100.912506  576.073120  948.339050
# 2023-12-26  48.121510  101.400002  581.030701  953.104675
# 2023-12-27  50.679150  100.912506  586.979797  991.228821
# 2023-12-28  49.731876  101.400002  587.971313  976.932190
# 2023-12-29  49.826603  101.887505  587.971313  967.401184
#
# [485 rows x 4 columns]

# %%
frame1 = frame.pct_change()
frame2 = frame1.fillna(0)
frame2
# Out:
#                   聯電        鴻海       台積電       聯發科
# Date
# 2022-01-03  0.000000  0.000000  0.000000  0.000000
# 2022-01-04 -0.006309  0.004854  0.039620  0.013043
# 2022-01-05  0.001587  0.053140 -0.009146  0.008584
# 2022-01-06 -0.006339 -0.018349 -0.009231 -0.034043
# 2022-01-07 -0.001595 -0.004673 -0.015528 -0.030837
# ...              ...       ...       ...       ...
# 2023-12-25  0.004000  0.000000 -0.001718  0.005050
# 2023-12-26  0.011952  0.004831  0.008606  0.005025
# 2023-12-27  0.053150 -0.004808  0.010239  0.040000
# 2023-12-28 -0.018692  0.004831  0.001689 -0.014423
# 2023-12-29  0.001905  0.004808  0.000000 -0.009756
#
# [485 rows x 4 columns]

# %%
import yfinance as yf
data = yf.download("NVDA", start="2022-01-01",end="2024-06-01")
NVDA = data[['Adj Close']]
NVDA.columns = ['NVIDIA']
NVDA
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 NVIDIA
# Date
# 2022-01-03   30.075630
# 2022-01-04   29.245886
# 2022-01-05   27.562426
# 2022-01-06   28.135557
# 2022-01-07   27.205965
# ...                ...
# 2024-05-24  106.460258
# 2024-05-28  113.891647
# 2024-05-29  114.815567
# 2024-05-30  110.490921
# 2024-05-31  109.624001
#
# [606 rows x 1 columns]
