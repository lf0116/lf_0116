# %%
url = 'https://opendata.cwa.gov.tw/api/v1/rest/datastore/F-C0032-001?Authorization=CWA-FD4A7706-A89E-4A27-8C8E-F6F2A2F1A698&format=JSON'

# %%
import requests

r = requests.get(url)
if r.status_code ==200:
    print("下載成功")
# Out:
# 下載成功

# %%
print(r.text)
# Out:
# {"success":"true","result":{"resource_id":"F-C0032-001","fields":[{"id":"datasetDescription","type":"String"},{"id":"locationName","type":"String"},{"id":"parameterName","type":"String"},{"id":"parameterValue","type":"String"},{"id":"parameterUnit","type":"String"},{"id":"startTime","type":"Timestamp"},{"id":"endTime","type":"Timestamp"}]},"records":{"datasetDescription":"三十六小時天氣預報","location":[{"locationName":"嘉義縣","weatherElement":[{"elementName":"Wx","time":[{"startTime":"2024-01-22 06:00:00","endTime":"2024-01-22 18:00:00","parameter":{"parameterName":"多雲短暫雨","parameterValue":"8"}},{"startTime":"2024-01-22 18:00:00","endTime":"2024-01-23 06:00:00","parameter":{"parameterName":"陰短暫雨","parameterValue":"11"}},{"startTime":"2024-01-23 06:00:00","endTime":"2024-01-23 18:00:00","parameter":{"parameterName":"陰時多雲短暫雨","parameterValue":"10"}}]},{"elementName":"PoP","time":[{"startTime":"2024-01-22 06:00:00","endTime":"2024-01-22 18:00:00","parameter":{"parameterName":"30","parameterUnit":
# ...

# %%
all_json = r.json()
locations = all_json['records']['location']
weather_list = [] #建立空的list
for item in locations:
    city_item = {} #建立空的dict
    city_item['城市'] = item['locationName']
    city_item['起始時間'] = item['weatherElement'][1]['time'][0]['startTime']
    city_item['結束時間'] = item['weatherElement'][1]['time'][0]['endTime']
    city_item['最高溫度'] = item['weatherElement'][4]['time'][0]['parameter']['parameterName']
    city_item['最低溫度'] = item['weatherElement'][2]['time'][0]['parameter']['parameterName']
    city_item['體感'] = item['weatherElement'][3]['time'][0]['parameter']['parameterName']
    weather_list.append(city_item)
weather_list
# Out:
# [{'城市': '嘉義縣',
#   '起始時間': '2024-01-26 00:00:00',
#   '結束時間': '2024-01-26 06:00:00',
#   '最高溫度': '11',
#   '最低溫度': '10',
#   '體感': '非常寒冷至寒冷'},
#  {'城市': '新北市',
#   '起始時間': '2024-01-26 00:00:00',
#   '結束時間': '2024-01-26 06:00:00',
#   '最高溫度': '12',
#   '最低溫度': '12',
#   '體感': '寒冷'},
#  {'城市': '嘉義市',
#   '起始時間': '2024-01-26 00:00:00',
#   '結束時間': '2024-01-26 06:00:00',
#   '最高溫度': '11',
#   '最低溫度': '10',
#   '體感': '非常寒冷至寒冷'},
#  {'城市': '新竹縣',
#   '起始時間': '2024-01-26 00:00:00',
#   '結束時間': '2024-01-26 06:00:00',
#   '最高溫度': '11',
#   '最低溫度': '10',
#   '體感': '非常寒冷至寒冷'},
#  {'城市': '新竹市',
#   '起始時間': '2024-01-26 00:00:00',
#   '結束時間': '2024-01-26 06:00:00',
#   '最高溫度': '11',
#   '最低溫度': '10',
#   '體感': '非常寒冷至寒冷'},
#  {'城市': '臺北市',
#   '起始時間': '2024-01-26 00:00:00',
#   '結束時間': '2024-01-26 06:00:00',
#   '最高溫度': '12',
#   '最低溫度': '12',
#   '體感': '寒冷'},
#  {'城市': '臺南市',
#   '起始時間': '2024-01-26 00:00:00',
#   '結束時間': '2024-01-26 06:00:00',
#   '最高溫度': '13',
#   '最低溫度': '12',
#   '體感': '寒冷'},
# ...

# %%
import csv
with open('目前各縣市天氣預測.csv', mode = 'w', encoding= 'utf-8', newline ="") as file:
    writer = csv.DictWriter(file,fieldnames= ['城市','起始時間','結束時間','最高溫度','最低溫度','體感'])
    writer.writeheader()
    writer.writerows(weather_list)
print("存檔成功")
# Out:
# 存檔成功

# %%
import pandas as pd
weather_df = pd.DataFrame(weather_list)
weather_df
# Out:
#      城市                 起始時間                 結束時間 最高溫度 最低溫度       體感
# 0   嘉義縣  2024-01-26 00:00:00  2024-01-26 06:00:00   11   10  非常寒冷至寒冷
# 1   新北市  2024-01-26 00:00:00  2024-01-26 06:00:00   12   12       寒冷
# 2   嘉義市  2024-01-26 00:00:00  2024-01-26 06:00:00   11   10  非常寒冷至寒冷
# 3   新竹縣  2024-01-26 00:00:00  2024-01-26 06:00:00   11   10  非常寒冷至寒冷
# 4   新竹市  2024-01-26 00:00:00  2024-01-26 06:00:00   11   10  非常寒冷至寒冷
# 5   臺北市  2024-01-26 00:00:00  2024-01-26 06:00:00   12   12       寒冷
# 6   臺南市  2024-01-26 00:00:00  2024-01-26 06:00:00   13   12       寒冷
# 7   宜蘭縣  2024-01-26 00:00:00  2024-01-26 06:00:00   12   12       寒冷
# 8   苗栗縣  2024-01-26 00:00:00  2024-01-26 06:00:00   10   10     非常寒冷
# 9   雲林縣  2024-01-26 00:00:00  2024-01-26 06:00:00   11   10  非常寒冷至寒冷
# 10  花蓮縣  2024-01-26 00:00:00  2024-01-26 06:00:00   15   14       寒冷
# 11  臺中市  2024-01-26 00:00:00  2024-01-26 06:00:00   12   11       寒冷
# 12  臺東縣  2024-01-26 00:00:00  2024-01-26 06:00:00   16   15  寒冷至稍有寒意
# ...
