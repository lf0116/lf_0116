# %%
import numpy as np
import pandas as pd

url = 'https://raw.githubusercontent.com/roberthsu2003/PythonForDataAnalysis/master/%E6%95%B8%E6%93%9A%E6%95%B4%E7%90%86_%E9%80%A3%E6%8E%A5_%E5%90%88%E4%BD%B5_%E9%87%8D%E5%A1%91/%E6%AD%B7%E5%B9%B4%E5%9C%8B%E5%85%A7%E4%B8%BB%E8%A6%81%E8%A7%80%E5%85%89%E9%81%8A%E6%86%A9%E6%93%9A%E9%BB%9E%E9%81%8A%E5%AE%A2%E4%BA%BA%E6%95%B8%E6%9C%88%E5%88%A5%E7%B5%B1%E8%A8%88.csv'
dataframe = pd.read_csv(url, encoding = 'utf-8')
dataframe
# Out:
#         年別    類型    觀光遊憩區       細分  縣市別         1月         2月         3月  \
# 0     2012  國家公園  陽明山國家公園  陽明山遊客中心  臺北市    12187.0    18612.0    18580.0
# 1     2012  國家公園  陽明山國家公園     陽明書屋  臺北市     2597.0     3617.0     5221.0
# 2     2012  國家公園  陽明山國家公園     陽明公園  臺北市   161000.0   463000.0   705200.0
# 3     2012  國家公園  陽明山國家公園    大屯遊憩區  臺北市    17047.0    29079.0    38558.0
# 4     2012  國家公園  陽明山國家公園   龍鳳谷遊憩區  臺北市    21201.0    22134.0    62447.0
# ...    ...   ...      ...      ...  ...        ...        ...        ...
# 3060  2021    其他        -   霧峰林家園區  臺中市    17919.0    22413.0    14562.0
# 3061  2021    其他        -  臺中國家歌劇院  臺中市    70761.0    58994.0    72877.0
# 3062  2021    其他        -     一中商圈  臺中市  1142577.0  1227190.0  1167561.0
# 3063  2021    其他        -     逢甲夜市  臺中市   592042.0   672055.0   698734.0
# 3064  2021    其他        -   潭雅神綠園道  臺中市   296840.0   405427.0   359029.0
#
#              4月        5月        6月        7月        8月        9月        10月  \
# 0       13329.0   14179.0   11397.0   16000.0   11791.0   10469.0    11515.0
# 1        4317.0    3497.0    2815.0    3005.0    2497.0    2764.0     3701.0
# 2       85600.0   38600.0   28000.0   51700.0   44700.0   39000.0    36000.0
# 3       34332.0   43906.0   42586.0   63721.0   41881.0   51743.0    38214.0
# 4       64691.0   16243.0   15811.0   15787.0   16963.0   16176.0    18951.0
# ...         ...       ...       ...       ...       ...       ...        ...
# 3060    20850.0    6404.0       0.0     633.0    3896.0    8249.0    15638.0
# 3061    84679.0   39116.0       0.0    3508.0   33553.0   48770.0    91325.0
# 3062  1033384.0  415927.0  165821.0  348837.0  515960.0  651131.0  1053106.0
# 3063   565853.0  259384.0   93986.0  231645.0  398605.0  482115.0   658506.0
# 3064   599560.0  217254.0       0.0  267140.0  361479.0  389770.0   408215.0
#
#           11月      12月       合計
# 0      6896.0   9631.0   154586
# 1      2863.0   2983.0    39877
# 2     35000.0  33000.0  1720800
# 3     27467.0  27306.0   455840
# 4     18136.0  19135.0   307675
# ...       ...      ...      ...
# 3060      NaN      NaN   110564
# 3061      NaN      NaN   503583
# 3062      NaN      NaN  7721494
# 3063      NaN      NaN  4652925
# 3064      NaN      NaN  3304714
#
# [3065 rows x 18 columns]

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3065 entries, 0 to 3064
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   年別      3065 non-null   int64
#  1   類型      3065 non-null   object
#  2   觀光遊憩區   3065 non-null   object
#  3   細分      3065 non-null   object
#  4   縣市別     3065 non-null   object
#  5   1月      3064 non-null   float64
#  6   2月      3064 non-null   float64
#  7   3月      3064 non-null   float64
#  8   4月      3064 non-null   float64
#  9   5月      3064 non-null   float64
#  10  6月      3064 non-null   float64
#  11  7月      3064 non-null   float64
#  12  8月      3064 non-null   float64
#  13  9月      3064 non-null   float64
#  14  10月     3064 non-null   float64
#  15  11月     2741 non-null   float64
#  16  12月     2741 non-null   float64
#  17  合計      3065 non-null   int64
# dtypes: float64(12), int64(2), object(4)
# memory usage: 431.1+ KB

# %%
#個年分，每個縣市，每月的觀光人數
dataframe1 = dataframe.drop(columns = ['類型', '觀光遊憩區', '細分'])
dataframe1
# Out:
#         年別  縣市別         1月         2月         3月         4月        5月  \
# 0     2012  臺北市    12187.0    18612.0    18580.0    13329.0   14179.0
# 1     2012  臺北市     2597.0     3617.0     5221.0     4317.0    3497.0
# 2     2012  臺北市   161000.0   463000.0   705200.0    85600.0   38600.0
# 3     2012  臺北市    17047.0    29079.0    38558.0    34332.0   43906.0
# 4     2012  臺北市    21201.0    22134.0    62447.0    64691.0   16243.0
# ...    ...  ...        ...        ...        ...        ...       ...
# 3060  2021  臺中市    17919.0    22413.0    14562.0    20850.0    6404.0
# 3061  2021  臺中市    70761.0    58994.0    72877.0    84679.0   39116.0
# 3062  2021  臺中市  1142577.0  1227190.0  1167561.0  1033384.0  415927.0
# 3063  2021  臺中市   592042.0   672055.0   698734.0   565853.0  259384.0
# 3064  2021  臺中市   296840.0   405427.0   359029.0   599560.0  217254.0
#
#             6月        7月        8月        9月        10月      11月      12月  \
# 0      11397.0   16000.0   11791.0   10469.0    11515.0   6896.0   9631.0
# 1       2815.0    3005.0    2497.0    2764.0     3701.0   2863.0   2983.0
# 2      28000.0   51700.0   44700.0   39000.0    36000.0  35000.0  33000.0
# 3      42586.0   63721.0   41881.0   51743.0    38214.0  27467.0  27306.0
# 4      15811.0   15787.0   16963.0   16176.0    18951.0  18136.0  19135.0
# ...        ...       ...       ...       ...        ...      ...      ...
# 3060       0.0     633.0    3896.0    8249.0    15638.0      NaN      NaN
# 3061       0.0    3508.0   33553.0   48770.0    91325.0      NaN      NaN
# 3062  165821.0  348837.0  515960.0  651131.0  1053106.0      NaN      NaN
# 3063   93986.0  231645.0  398605.0  482115.0   658506.0      NaN      NaN
# 3064       0.0  267140.0  361479.0  389770.0   408215.0      NaN      NaN
#
#            合計
# 0      154586
# 1       39877
# 2     1720800
# 3      455840
# 4      307675
# ...       ...
# 3060   110564
# 3061   503583
# 3062  7721494
# 3063  4652925
# 3064  3304714
#
# [3065 rows x 15 columns]

# %%
dataframe2 = dataframe1.set_index(['年別', '縣市別'])
dataframe2
# Out:
#                  1月         2月         3月         4月        5月        6月  \
# 年別   縣市別
# 2012 臺北市    12187.0    18612.0    18580.0    13329.0   14179.0   11397.0
#      臺北市     2597.0     3617.0     5221.0     4317.0    3497.0    2815.0
#      臺北市   161000.0   463000.0   705200.0    85600.0   38600.0   28000.0
#      臺北市    17047.0    29079.0    38558.0    34332.0   43906.0   42586.0
#      臺北市    21201.0    22134.0    62447.0    64691.0   16243.0   15811.0
# ...             ...        ...        ...        ...       ...       ...
# 2021 臺中市    17919.0    22413.0    14562.0    20850.0    6404.0       0.0
#      臺中市    70761.0    58994.0    72877.0    84679.0   39116.0       0.0
#      臺中市  1142577.0  1227190.0  1167561.0  1033384.0  415927.0  165821.0
#      臺中市   592042.0   672055.0   698734.0   565853.0  259384.0   93986.0
#      臺中市   296840.0   405427.0   359029.0   599560.0  217254.0       0.0
#
#                 7月        8月        9月        10月      11月      12月       合計
# 年別   縣市別
# 2012 臺北市   16000.0   11791.0   10469.0    11515.0   6896.0   9631.0   154586
#      臺北市    3005.0    2497.0    2764.0     3701.0   2863.0   2983.0    39877
#      臺北市   51700.0   44700.0   39000.0    36000.0  35000.0  33000.0  1720800
#      臺北市   63721.0   41881.0   51743.0    38214.0  27467.0  27306.0   455840
#      臺北市   15787.0   16963.0   16176.0    18951.0  18136.0  19135.0   307675
# ...            ...       ...       ...        ...      ...      ...      ...
# 2021 臺中市     633.0    3896.0    8249.0    15638.0      NaN      NaN   110564
#      臺中市    3508.0   33553.0   48770.0    91325.0      NaN      NaN   503583
#      臺中市  348837.0  515960.0  651131.0  1053106.0      NaN      NaN  7721494
#      臺中市  231645.0  398605.0  482115.0   658506.0      NaN      NaN  4652925
#      臺中市  267140.0  361479.0  389770.0   408215.0      NaN      NaN  3304714
#
# [3065 rows x 13 columns]

# %%
dataframe3 = dataframe2.groupby(level = ['年別', '縣市別']).sum()
dataframe3
# Out:
#                  1月         2月         3月         4月         5月        6月  \
# 年別   縣市別
# 2012 南投縣  1499117.0  1746048.0  1536266.0  1663162.0  1263997.0  921177.0
#      嘉義市    91527.0   103501.0   114432.0   118553.0   108170.0  111128.0
#      嘉義縣   148953.0   168450.0   383193.0   274784.0   199686.0   95847.0
#      基隆市    25460.0    25975.0    28478.0    49756.0    39617.0   42039.0
#      宜蘭縣   488346.0   366411.0   299170.0   647395.0   473734.0  368535.0
# ...             ...        ...        ...        ...        ...       ...
# 2021 苗栗縣   487921.0   606775.0   241834.0   306392.0   121347.0     511.0
#      連江縣     4562.0     3918.0     8116.0    24900.0    16531.0       0.0
#      金門縣   113656.0    90730.0   134745.0   175182.0   104525.0       0.0
#      雲林縣   662808.0  2211386.0  1002384.0  2811636.0   398096.0     300.0
#      高雄市  1592975.0  2663144.0  1413914.0  1607953.0   745693.0  121448.0
#
#                  7月         8月         9月        10月        11月        12月  \
# 年別   縣市別
# 2012 南投縣  1759512.0  1572730.0  1163129.0  1438261.0  1397173.0  1414820.0
#      嘉義市   118170.0   115085.0   113022.0   115793.0   116902.0   119168.0
#      嘉義縣   197300.0    52064.0   123287.0   190067.0   203166.0   201484.0
#      基隆市    50342.0    45135.0    42350.0    48473.0    33434.0    25954.0
#      宜蘭縣   957592.0   665604.0   348909.0   473010.0   419884.0   357550.0
# ...             ...        ...        ...        ...        ...        ...
# 2021 苗栗縣    18208.0    71275.0    98492.0   153972.0        0.0        0.0
#      連江縣      306.0     2318.0     4525.0     6582.0        0.0        0.0
#      金門縣      477.0     8776.0    20670.0    55476.0        0.0        0.0
#      雲林縣     6545.0   199537.0   221936.0   251157.0        0.0        0.0
#      高雄市   245984.0   558874.0   774677.0  1201949.0        0.0        0.0
#
#                 合計
# 年別   縣市別
# 2012 南投縣  17375392
#      嘉義市   1345451
#      嘉義縣   2238281
#      基隆市    457013
#      宜蘭縣   5866140
# ...            ...
# 2021 苗栗縣   2106727
#      連江縣     71758
#      金門縣    704237
#      雲林縣   7765785
#      高雄市  10926611
#
# [220 rows x 13 columns]

# %%
dataframe3.columns.name = "月份"
dataframe4 = dataframe3.stack().unstack(level  = ['縣市別', '月份'])
dataframe4.to_excel('表單1.xlsx')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 3
#       1 dataframe3.columns.name = "月份"
#       2 dataframe4 = dataframe3.stack().unstack(level  = ['縣市別', '月份'])
# ----> 3 dataframe4.to_excel('表單1.xlsx')
#
# File c:\Python310\lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Python310\lib\site-packages\pandas\core\generic.py:2417, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2404 from pandas.io.formats.excel import ExcelFormatter
#    2406 formatter = ExcelFormatter(
#    2407     df,
#    2408     na_rep=na_rep,
#    (...)
#    2415     inf_rep=inf_rep,
#    2416 )
# -> 2417 formatter.write(
#    2418     excel_writer,
#    2419     sheet_name=sheet_name,
#    2420     startrow=startrow,
#    2421     startcol=startcol,
#    2422     freeze_panes=freeze_panes,
#    2423     engine=engine,
#    2424     storage_options=storage_options,
#    2425     engine_kwargs=engine_kwargs,
#    2426 )
#
# File c:\Python310\lib\site-packages\pandas\io\formats\excel.py:952, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     949     need_save = True
#     951 try:
# --> 952     writer._write_cells(
#     953         formatted_cells,
#     954         sheet_name,
#     955         startrow=startrow,
#     956         startcol=startcol,
#     957         freeze_panes=freeze_panes,
#     958     )
#     959 finally:
#     960     # make sure to close opened file handles
#     961     if need_save:
#
# File c:\Python310\lib\site-packages\pandas\io\excel\_openpyxl.py:486, in OpenpyxlWriter._write_cells(self, cells, sheet_name, startrow, startcol, freeze_panes)
#     481     freeze_panes = cast(tuple[int, int], freeze_panes)
#     482     wks.freeze_panes = wks.cell(
#     483         row=freeze_panes[0] + 1, column=freeze_panes[1] + 1
#     484     )
# --> 486 for cell in cells:
#     487     xcell = wks.cell(
#     488         row=startrow + cell.row + 1, column=startcol + cell.col + 1
#     489     )
#     490     xcell.value, fmt = self._value_with_fmt(cell.val)
#
# File c:\Python310\lib\site-packages\pandas\io\formats\excel.py:890, in ExcelFormatter.get_formatted_cells(self)
#     888 def get_formatted_cells(self) -> Iterable[ExcelCell]:
#     889     for cell in itertools.chain(self._format_header(), self._format_body()):
# --> 890         cell.val = self._format_value(cell.val)
#     891         yield cell
#
# File c:\Python310\lib\site-packages\pandas\io\formats\excel.py:602, in ExcelFormatter._format_value(self, val)
#     600 if missing.isposinf_scalar(val):
#     601     val = self.inf_rep
# --> 602 elif missing.isneginf_scalar(val):
#     603     val = f"-{self.inf_rep}"
#     604 elif self.float_format is not None:
#
# KeyboardInterrupt:
