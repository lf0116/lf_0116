# %%
#標準寫法
import matplotlib.pyplot as plt


#製作figure
fig = plt.figure()

#在1的figure上製作一個軸
ax_1 = fig.add_subplot(1,1,1)

#將圖的數據存儲在axes中

X = [5, 3, 9]
Y = [3, 4, 5]
ax_1.plot(X, Y)

#顯示圖表
plt.show()

# %%
figure = plt.figure()
axes1 = figure.add_subplot(1,3,1)
axes1.set_title('plot1')
axes2 = figure.add_subplot(1,3,2)
axes2.set_title('plot2')
axes3 = figure.add_subplot(1,3,3)
axes3.set_title('plot3')
# Out:
# Text(0.5, 1.0, 'plot3')

# %%
import matplotlib.pyplot as plt

data = [-1, -4.3, 15, 21, 31]
figure = plt. figure(figsize = (8,5))
axes = figure.add_subplot()
axes.plot(data,'rD') #r後面的代表marker的符號

# %%
student1 = {'chinese':78, 'english':80, 'math':92, 'history':75, 'science': 85}
student1.keys() #傳出keys
student1.values()

figure = plt.figure(figsize = (8,5), dpi = 250, facecolor = '#cccccc')
axes1 = figure.add_subplot()
axes1.plot(student1.keys(), student1.values(), 'r--+', label = 'student1')


student2 = {'chinese':92, 'english':60, 'math':85, 'history':62, 'science':73}
axes1.plot(student2.keys(), student2.values(), 'b:+', label ='student2')
axes1.legend()
plt.show()

# %%
#使用codespace安裝中文字型
#install 要加y
#命令列：sudo apt-get update -y
#命令列：sudo apt-get install -y fonts-wqy-zenhei

import matplotlib. pyplot as plt
from matplotlib.font_manager import FontProperties
font = FontProperties(fname = '/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc', size = 8)
font1 = FontProperties(fname = '/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc', size = 12)

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '自然': 85} #x軸,屬性dict
student1.keys() #傳出keys
student1.values()

figure = plt.figure(figsize = (8,5), dpi = 250, facecolor = '#cccccc')
axes1 = figure.add_subplot()
axes1.plot(student1.keys(), student1.values(), 'r--+', label = 'student1')
axes1.set_xticklabels(student1.keys(),fontproperties = font)
plt.show()
# Out:
# /tmp/ipykernel_26394/2563203299.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes1.set_xticklabels(student1.keys(),fontproperties = font)

# %%
import matplotlib. pyplot as plt
from matplotlib.font_manager import FontProperties
font = FontProperties(fname = '/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc', size = 8)
font1 = FontProperties(fname = '/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc', size = 12)

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '自然': 85} #x軸,屬性dict
student2 = {'國文':92, '英文':60, '數學':85, '歷史':62, '自然':73}
student1.keys() #傳出keys
student1.values()

figure = plt.figure(figsize =[8,5], facecolor ='#cccccc')
axes = figure.add_subplot(1,1,1)
student1_value_list = list(student1.values()) #student1.values()是dict, 非list
student2_value_list = list(student2.values())

axes.plot(student1.keys(), student1_value_list, 'r--+', label = "學生1")
axes.plot(student2.keys(), student2_value_list, 'b-.D', label = "學生2")
axes.set_xticklabels(student1.keys(), fontproperties = font)
axes.set_title("學生分數", fontproperties = font1)
axes.set_xlabel("科目", fontproperties = font)
axes.set_ylabel("分數", fontproperties = font)
axes.grid(axis = 'y')
axes.legend(prop = font)
#axes.annotate("75",[x,y] )
xlocation = axes.get_xticks()
#ylocation = axes.get_yticks()

xtick_count = len(xlocation) #xlocation索引
for i in range(xtick_count):
    x = xlocation[i]
    y1 = student1_value_list[i]
    y2 = student2_value_list[i]
    axes.annotate(str(y1), [x,y1])
    axes.annotate(str(y2), [x,y2])

plt.show()
# Out:
# /tmp/ipykernel_8699/2384336838.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes.set_xticklabels(student1.keys(), fontproperties = font)
